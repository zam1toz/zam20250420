# %%
from tools import FlightSearchTool
from pprint import pprint

flights = FlightSearchTool().run(origin_city='인천', destination_city='오사카', departure_date='2025-05-01', adults = 1)
pprint(flights)
# Out:
# Using Tool: 항공편 검색 도구
# [{'가격': '69100.00',
#   '도착시간': '2025-05-01T10:05:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T08:00:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '301',
#   '항공사': 'TW'},
#  {'가격': '69100.00',
#   '도착시간': '2025-05-01T18:05:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T15:55:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '305',
#   '항공사': 'TW'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T09:00:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T07:10:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '1301',
#   '항공사': '7C'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T11:00:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T09:10:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '1303',
#   '항공사': '7C'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T18:50:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T17:00:00',
#   '출발일': '2025-05-01',
# ...

# %%
from tools import HotelSearchTool
from pprint import pprint

hotels = HotelSearchTool().run(city_name='오사카', check_in_date='2025-05-01', check_out_date='2025-05-03', adults = 1, max_hotels = 3)
pprint(hotels)
# Out:
# Using Tool: 숙소 검색 도구
# [{'check_in': '2025-05-01',
#   'check_out': '2025-05-03',
#   'currency': 'JPY',
#   'hotel_name': 'Osaka Marriott Miyako Hotel',
#   'room_description': 'Non-refundable discount\n'
#                       'Superior, located on 39-49th floors, sweeping\n'
#                       'skyline view from 198-236m above the ground,',
#   'total_price': '164703'}]

# %%
from tools import NearbyPlacesTool
from pprint import pprint

nearby_places = NearbyPlacesTool().run(place_name='웨스턴 오사카', radius = 500)
pprint(nearby_places)
# Out:
# Using Tool: 인근 장소 검색 도구
# [{'리뷰': [{'내용': '일본 여행에서 많이 걸어서 발이 너무 아팠는데 이곳에서 마사지를 받고 회복했습니다. 너무 강력하게 하거나, '
#                 '약하게 하지않고 알맞게 좋았습니다. 그들은 친절하고 프로입니다. 필요한 부분을 명확히 알고, 제안에도 귀기울여 '
#                 '줍니다. 다음에 오사카에 간다면 또 가고 싶습니다. 가격도 다른곳과 비교하여 저렴합니다.',
#           '평점': 5},
#          {'내용': '굉장히 친절하시고 성심껏 마사지 해주셨습니다. 하루종일 걸어다녀서 피곤했는데 족욕과 안마코스에 발마사지 코스 '
#                 '합쳐서 푹 쉬었습니다.',
#           '평점': 5},
#          {'내용': '호텔 근처라서 다녀왔는데 집중적으로 필요한 곳을 세세하게 물어보고 해주셔서 좋았어요!', '평점': 5}],
#   '영업시간': ['월요일: 오전 10:00 ~ 오후 7:00',
#            '화요일: 오전 10:00 ~ 오후 7:00',
#            '수요일: 오전 10:00 ~ 오후 7:00',
#            '목요일: 오전 10:00 ~ 오후 7:00',
#            '금요일: 오전 10:00 ~ 오후 7:00',
#            '토요일: 오전 10:00 ~ 오후 7:00',
#            '일요일: 휴무일'],
#   '웹사이트': 'https://qr.paps.jp/CkcBE',
#   '이름': '手もみ処 RECOVER 東心斎橋店 ～Japanese Traditional Massage, produced by '
#         'RECOVER～',
#   '전화번호': '06-6281-5002',
# ...

# %%
from tools import ExchangeRateTool
from pprint import pprint

exchange_rate = ExchangeRateTool().run(from_currency='USD', to_currency='KRW', amount=1000)
pprint(exchange_rate)
# Out:
# Using Tool: 환율 도구
# {'conversion_rate': 1419.2853,
#  'converted_amount': 1419285.3,
#  'from_currency': 'USD',
#  'original_amount': 1000,
#  'to_currency': 'KRW'}
